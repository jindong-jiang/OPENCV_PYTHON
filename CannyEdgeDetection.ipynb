# %% [markdown]
# ## Canny Edge Detection

# %%
#1.Noise Reduction with the Gaussian filter
#2.Finding Intensity Gradient of the Image
#3.Non-maximum Suppression
#4.Hysteresis Thresholding

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread("pic4.jpeg",0)

# %%
plt.imshow(img,"gray")

# %%
edges=cv2.Canny(img,100,200)

# %%
plt.imshow(edges,"gray")

# %%
# %history
# Out:
# #1.Noise Reduction with the Gaussian filter
# #2.Finding Intensity Gradient of the Image
# #3.Non-maximum Suppression
# #4.Hysteresis Thresholding
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt
# img=cv2.imread("pic4.jpeg",0)
# plt.imshow(img,"gray")
# edges=cv2.Canny(img,100,200)
# plt.imshow(edges,"gray")
# %history

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img=cv2.imread("pic4.jpeg",0)
plt.imshow(img,"gray")

def drawEdge(p1):
    pass
    

cv2.namedWindow("imageEdge")
cv2.createTrackbar("th1","imageEdge",0,500,drawEdge)
cv2.createTrackbar("th2","imageEdge",0,500,drawEdge)
while(1):
    k=cv2.waitKey(1) & 0xFF
    if k==27:
        break
    p1=cv2.getTrackbarPos('th1','imageEdge')
    p2=cv2.getTrackbarPos('th2','imageEdge')
    edges=cv2.Canny(img,p1,p2)
    cv2.imshow("imageEdge",edges)
cv2.destroyAllWindows()
