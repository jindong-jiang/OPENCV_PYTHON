# %% [markdown]
# ## Image Gradients

# %%
import cv2

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
img=cv2.imread("pic4.jpeg")

# %%
laplacian=cv2.Laplacian(img,cv2.CV_64F)

# %%
sobelx=cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)

# %%
sobely=cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)

# %%
plt.subplot(221),plt.imshow(img)
plt.subplot(222),plt.imshow(laplacian,cmap="gray")
plt.subplot(223),plt.imshow(sobelx)
plt.subplot(224),plt.imshow(sobely)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fe887b56860>,
#  <matplotlib.image.AxesImage at 0x7fe887b32860>)

# %% [markdown]
# ## Output Datatype is important

# %%
img2=cv2.imread('double_edge.jpg',0)

# %%
sobelx8u=cv2.Sobel(img2,cv2.CV_8U,1,0,ksize=5)

# %%
plt.imshow(sobelx8u,"gray")

# %%
sobelx64f=cv2.Sobel(img2,cv2.CV_64F,1,0,ksize=5)

# %%
plt.imshow(sobelx64f,"gray")

# %%
## The output datatype should be kept to some higher forms
